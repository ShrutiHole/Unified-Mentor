# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"C:\Users\afl21\Downloads\Amazon Sales data.csv")

# %%
data
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
data.head(5)
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   Sales Channel Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# 0       Offline              H  5/28/2010  669165933  6/27/2010        9925
# 1        Online              C  8/22/2012  963881480  9/15/2012        2804
# 2       Offline              L   5/2/2014  341417157   5/8/2014        1779
# 3        Online              C  6/20/2014  514321792   7/5/2014        8102
# 4       Offline              L   2/1/2013  115456712   2/6/2013        5062
#
# ...

# %%
data.tail(5)
# Out:
#                 Region       Country      Item Type Sales Channel  \
# 95  Sub-Saharan Africa          Mali        Clothes        Online
# 96                Asia      Malaysia         Fruits       Offline
# 97  Sub-Saharan Africa  Sierra Leone     Vegetables       Offline
# 98       North America        Mexico  Personal Care       Offline
# 99  Sub-Saharan Africa    Mozambique      Household       Offline
#
#    Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 95              M   7/26/2011  512878119    9/3/2011         888      109.28
# 96              L  11/11/2011  810711038  12/28/2011        6267        9.33
# 97              C    6/1/2016  728815257   6/29/2016        1485      154.06
# 98              M   7/30/2015  559427106    8/8/2015        5767       81.73
# 99              L   2/10/2012  665095412   2/15/2012        5367      668.27
#
#     Unit Cost  Total Revenue  Total Cost  Total Profit
# ...

# %%
data.columns
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit', 'Year',
#        'Month'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          100 non-null    object
#  1   Country         100 non-null    object
#  2   Item Type       100 non-null    object
#  3   Sales Channel   100 non-null    object
#  4   Order Priority  100 non-null    object
#  5   Order Date      100 non-null    object
#  6   Order ID        100 non-null    int64
#  7   Ship Date       100 non-null    object
#  8   Units Sold      100 non-null    int64
#  9   Unit Price      100 non-null    float64
#  10  Unit Cost       100 non-null    float64
#  11  Total Revenue   100 non-null    float64
#  12  Total Cost      100 non-null    float64
#  13  Total Profit    100 non-null    float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 11.1+ KB

# %%
data.isnull()
# Out:
#     Region  Country  Item Type  Sales Channel  Order Priority  Order Date  \
# 0    False    False      False          False           False       False
# 1    False    False      False          False           False       False
# 2    False    False      False          False           False       False
# 3    False    False      False          False           False       False
# 4    False    False      False          False           False       False
# ..     ...      ...        ...            ...             ...         ...
# 95   False    False      False          False           False       False
# 96   False    False      False          False           False       False
# 97   False    False      False          False           False       False
# 98   False    False      False          False           False       False
# 99   False    False      False          False           False       False
#
#     Order ID  Ship Date  Units Sold  Unit Price  Unit Cost  Total Revenue  \
# ...

# %%
data.shape
# Out:
# (100, 14)

# %%
data.dtypes
# Out:
# Region             object
# Country            object
# Item Type          object
# Sales Channel      object
# Order Priority     object
# Order Date         object
# Order ID            int64
# Ship Date          object
# Units Sold          int64
# Unit Price        float64
# Unit Cost         float64
# Total Revenue     float64
# Total Cost        float64
# Total Profit      float64
# dtype: object

# %%
data.describe()
# Out:
#            Order ID   Units Sold  Unit Price   Unit Cost  Total Revenue  \
# count  1.000000e+02   100.000000  100.000000  100.000000   1.000000e+02
# mean   5.550204e+08  5128.710000  276.761300  191.048000   1.373488e+06
# std    2.606153e+08  2794.484562  235.592241  188.208181   1.460029e+06
# min    1.146066e+08   124.000000    9.330000    6.920000   4.870260e+03
# 25%    3.389225e+08  2836.250000   81.730000   35.840000   2.687212e+05
# 50%    5.577086e+08  5382.500000  179.880000  107.275000   7.523144e+05
# 75%    7.907551e+08  7369.000000  437.200000  263.330000   2.212045e+06
# max    9.940222e+08  9925.000000  668.270000  524.960000   5.997055e+06
#
#          Total Cost  Total Profit
# count  1.000000e+02  1.000000e+02
# mean   9.318057e+05  4.416820e+05
# std    1.083938e+06  4.385379e+05
# min    3.612240e+03  1.258020e+03
# 25%    1.688680e+05  1.214436e+05
# 50%    3.635664e+05  2.907680e+05
# 75%    1.613870e+06  6.358288e+05
# max    4.509794e+06  1.719922e+06

# %%
data.nunique()
# Out:
# Region              7
# Country            76
# Item Type          12
# Sales Channel       2
# Order Priority      4
# Order Date        100
# Order ID          100
# Ship Date          99
# Units Sold         99
# Unit Price         12
# Unit Cost          12
# Total Revenue     100
# Total Cost        100
# Total Profit      100
# dtype: int64

# %%
data["Order Date"]=pd.to_datetime(data["Order Date"])

# %%
data['Year']=data['Order Date'].dt.year
data['Month']=data['Order Date'].dt.month

# %%
data["Total Revenue"]=data["Units Sold"]*data["Unit Price"]

# %%
monthlytrend=data.groupby(["Month"]).agg({"Total Revenue":"sum","Units Sold":"sum","Order ID":"count"}).reset_index()
print("monthly_trend:\n",monthlytrend)
# Out:
# monthly_trend:
#      Month  Total Revenue  Units Sold  Order ID
# 0       1    10482467.12       35742         7
# 1       2    24740517.77       71079        13
# 2       3     2274823.87       14497         4
# 3       4    16187186.33       44680         9
# 4       5    13215739.99       63651        11
# 5       6     5230325.77       34893        10
# 6       7    15669518.50       76201        12
# 7       8     1128164.91       17251         4
# 8       9     5314762.56       30101         5
# 9      10    15287576.61       55472        11
# 10     11    20568222.76       53261         9
# 11     12     7249462.12       16043         5

# %%
yearlytrend=data.groupby(["Year"]).agg({"Total Revenue":"sum","Units Sold":"sum","Order ID":"count"}).reset_index()
print("yearly_trend:\n",yearlytrend)
# Out:
# yearly_trend:
#     Year  Total Revenue  Units Sold  Order ID
# 0  2010    19186024.92       61571        10
# 1  2011    11129166.07       54768        12
# 2  2012    31898644.52       97967        22
# 3  2013    20330448.66       64663        12
# 4  2014    16630214.43       92040        15
# 5  2015    12427982.86       49480        11
# 6  2016    12372867.22       43156        10
# 7  2017    13373419.63       49226         8

# %%
monthlyyearlytrend=data.groupby(["Year"]).agg({"Total Revenue":"sum","Units Sold":"sum","Order ID":"count"}).reset_index()
print("monthly_yearly_trend:\n",monthlyyearlytrend)
# Out:
# monthly_yearly_trend:
#     Year  Total Revenue  Units Sold  Order ID
# 0  2010    19186024.92       61571        10
# 1  2011    11129166.07       54768        12
# 2  2012    31898644.52       97967        22
# 3  2013    20330448.66       64663        12
# 4  2014    16630214.43       92040        15
# 5  2015    12427982.86       49480        11
# 6  2016    12372867.22       43156        10
# 7  2017    13373419.63       49226         8

# %%
correlationmatrix=data[["Total Revenue","Units Sold","Unit Price"]].corr()
print("correlation_matrix:\n",correlationmatrix)
# Out:
# correlation_matrix:
#                 Total Revenue  Units Sold  Unit Price
# Total Revenue       1.000000    0.447784    0.752360
# Units Sold          0.447784    1.000000   -0.070486
# Unit Price          0.752360   -0.070486    1.000000

# %%
regionalsales=data.groupby(["Region"]).agg({"Total Revenue":"sum","Units Sold":"sum"}).reset_index()
print("Regional Sales Performance:\n",regionalsales)
# Out:
# Regional Sales Performance:
#                                Region  Total Revenue  Units Sold
# 0                               Asia    21347091.02       59967
# 1              Australia and Oceania    14094265.13       68325
# 2  Central America and the Caribbean     9170385.49       35771
# 3                             Europe    33368932.11       98117
# 4       Middle East and North Africa    14052706.58       48678
# 5                      North America     5643356.55       19143
# 6                 Sub-Saharan Africa    39672031.43      182870

# %%
sns.scatterplot(x='Units Sold', y='Total Revenue', data=data)
plt.title('Total Revenue vs Units Sold')
plt.xlabel('Units Sold')
plt.ylabel('Total Revenue')
plt.legend(bbox_to_anchor=(1,1),loc=2)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
sns.scatterplot(x='Unit Price', y='Total Revenue', data=data)
plt.title('Total Revenue vs Unit Price')
plt.xlabel('Unit Price')
plt.ylabel('Total Revenue')
plt.legend(bbox_to_anchor=(1,1),loc=2)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
sns.scatterplot(x='Unit Price', y='Units Sold', data=data)
plt.title('Units Sold vs Unit Price')
plt.xlabel('Unit Price')
plt.ylabel('Units Sold')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.histplot(data['Total Revenue'], bins=30, kde=True)
plt.title('Distribution of Total Revenue')
plt.xlabel('Total Revenue')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.histplot(data['Units Sold'], bins=30, kde=True)
plt.title('Distribution of Units Sold')
plt.xlabel('Units Sold')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.histplot(data['Unit Price'], bins=30, kde=True)
plt.title('Distribution of Unit Price')
plt.xlabel('Unit Price')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.lineplot(data=monthlytrend, x='Month', y='Total Revenue')
plt.title("Monthly Sales Trend")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.lineplot(data=yearlytrend, x='Year', y='Total Revenue')
plt.title("Yearly Sales Trend")
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=monthlytrend, x='Month', y='Total Revenue')
plt.title('Monthly Sales Trend')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=yearlytrend, x='Year', y='Total Revenue')
plt.title('Yearly Sales Trend')
plt.show()

# %%
monthlysales = data.groupby(['Year', 'Month']).agg({"Total Revenue": 'sum',"Units Sold": 'sum'}).reset_index()
plt.figure(figsize=(12, 6))
plt.plot(pd.to_datetime(monthlysales[['Year', 'Month']].assign(Day=1)), monthlysales['Total Revenue'])
plt.title('Monthly Sales Trend')
plt.xlabel('Date')
plt.ylabel('Total Revenue')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
